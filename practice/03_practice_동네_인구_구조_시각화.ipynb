# %% [markdown]
# ### 내가 거주하는 지역(동)의 인구 구조 시각화하기

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
import csv
f = open('age.csv', encoding = 'cp949')
data = csv.reader(f)

result=[]

for row in data:
  if '보람동' in row[0]:
    for i in row[3:]:
      result.append(int(i.replace(',',''))) #인구 수 데이터 정수로 반환 후 result 변수에 담기

print(result)
# Out:
# [249, 239, 264, 307, 291, 308, 354, 342, 291, 299, 270, 257, 238, 202, 196, 186, 151, 174, 131, 137, 172, 169, 148, 155, 169, 170, 214, 194, 168, 220, 253, 237, 288, 258, 321, 383, 444, 426, 432, 421, 350, 345, 328, 333, 336, 338, 297, 285, 233, 206, 233, 195, 181, 179, 216, 148, 191, 181, 168, 161, 141, 126, 106, 119, 83, 88, 76, 57, 54, 72, 52, 50, 33, 18, 20, 26, 30, 22, 11, 15, 19, 13, 13, 16, 9, 11, 5, 8, 10, 5, 6, 3, 4, 1, 3, 1, 0, 1, 0, 0, 1]

# %%
import matplotlib.pyplot as plt

plt.figure(dpi=200)
plt.rc('font', family = 'NanumBarunGothic') # 나눔 바른 고딕을 기본 글꼴로 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지
plt.style.use('ggplot') #격자 무늬 스타일로 지정

plt.plot(result)
plt.title('세종 보람동 인구 구조')
plt.show()
