# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
import csv

f = open('subwayfee.csv')
data = csv.reader(f)
next(data)
label=['유임승차','유임하차','무임승차','무임하차']
id = []
SumList = []*25
temp = []

for row in data:
  for i in range(4,8):
    row[i] = int(row[i])
  if row[1] != id:
    id.append(row[1])
  id = list(set(id))  

  if row[1] == '1호선':
    temp.append(row[4])
    SumList=sum(temp)

print(id)
print(sum(temp))
print(SumList)
# Out:
# ['2호선', '4호선', '7호선', '6호선', '9호선2~3단계', '5호선', '안산선', '경원선', '중앙선', '3호선', '분당선', '경의선', '경춘선', '9호선', '경인선', '과천선', '일산선', '경부선', '수인선', '공항철도 1호선', '우이신설선', '1호선', '경강선', '8호선', '장항선']
# 6309669
# 6309669

# %%
import csv
import matplotlib.pyplot as plt

f = open('subwayfee.csv')
data = csv.reader(f)
next(data)
label=['유임승차','유임하차','무임승차','무임하차']
id = []
SumList = [0]*4
temp = []

for row in data:
  if row[1] != id:
    id.append(row[1])
  id = list(set(id)) 
  for i in range(4,8):
    row[i] = int(row[i])
    if row[1] == '1호선':
      temp.append(row[i])
      SumList[i-4] = sum(temp)
      temp.clear()


print(SumList)

'''
  for j in range(len(id)):
    if row[1] == id[j]:
      row[4] = int(row[4])
      temp.append(row[4])
      SumList[j]=sum(temp)
      temp.clear()
'''

plt.figure(dpi=300)
plt.title('1호선의 승하차 비율')
plt.pie(SumList[0:4],labels=label,autopct='%1.f%%')
plt.axis('equal')

plt.show()
# Out:
# [174683, 188711, 146034, 147551]

# %%
import csv
import matplotlib.pyplot as plt

f = open('subwayfee.csv')
data = csv.reader(f)
next(data)
label=['유임승차','유임하차','무임승차','무임하차']
id = []
SumList = [0]*4
temp = []

for row in data:
  if row[1] != id:
    id.append(row[1])
  id = list(set(id)) 
  for i in range(4,8):
    row[i] = int(row[i])
    if row[1] == '1호선':
      temp.append(row[i])
      SumList[i-4] = sum(temp)
      temp.clear()


print(SumList)

'''
  for j in range(len(id)):
    if row[1] == id[j]:
      row[4] = int(row[4])
      temp.append(row[4])
      SumList[j]=sum(temp)
      temp.clear()
'''

plt.figure(dpi=300)
plt.title('1호선의 승하차 비율')
plt.pie(SumList[0:4],labels=label,autopct='%1.f%%')
plt.axis('equal')

plt.show()
``
